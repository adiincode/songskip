# %% [markdown]
# <a href="https://colab.research.google.com/github/adiincode/songskip/blob/main/songwala01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/song_skip_dataset.csv")
print(df.head(20))
print(df.columns)
print(df.describe())
# Out:
#    user_id  age gender premium_user listening_time     mood      genre  \
# 0     U001   36   Male          Yes          Night    Focus        EDM
# 1     U001   36   Male          Yes        Morning  Relaxed  Classical
# 2     U001   36   Male          Yes      Afternoon  Relaxed       Rock
# 3     U001   36   Male          Yes          Night      Sad  Bollywood
# 4     U001   36   Male          Yes          Night      Sad  Bollywood
# 5     U001   36   Male          Yes        Morning    Happy        Pop
# 6     U001   36   Male          Yes        Evening  Relaxed       Rock
# 7     U001   36   Male          Yes        Morning  Relaxed    Hip-Hop
# 8     U001   36   Male          Yes      Afternoon      Sad  Bollywood
# 9     U001   36   Male          Yes        Morning      Sad        EDM
# 10    U001   36   Male          Yes          Night      Sad    Hip-Hop
# 11    U001   36   Male          Yes        Morning      Gym       Jazz
# ...

# %%
print(df.describe())
# Out:
#                age  danceability       energy      valence  acousticness  \
# count  4000.000000   4000.000000  4000.000000  4000.000000   4000.000000
# mean     30.510000      0.551650     0.548370     0.554227      0.498892
# std       8.713718      0.261334     0.261967     0.259249      0.286748
# min      16.000000      0.100000     0.100000     0.100000      0.000000
# 25%      22.000000      0.320000     0.320000     0.330000      0.250000
# 50%      31.000000      0.560000     0.550000     0.560000      0.500000
# 75%      38.000000      0.780000     0.780000     0.780000      0.740000
# max      45.000000      1.000000     1.000000     1.000000      1.000000
#
#        speechiness  instrumentalness     liveness        tempo  loudness_db  \
# count  4000.000000       4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.399597          0.498770     0.507603   130.088500   -22.553750
# std       0.229347          0.290877     0.289733    40.839051    13.252642
# ...

# %%
print(df.head())
print(df.tail())
print(df.shape)
print(df.columns)
print(df.info())
print(df.describe())
print(df.isnull().sum())
print(df.duplicated().sum())
print(df.nunique())
df.dtypes
# Out:
# user_id             0
# age                 0
# gender              0
# premium_user        0
# listening_time      0
# mood                0
# genre               0
# danceability        0
# energy              0
# valence             0
# acousticness        0
# speechiness         0
# instrumentalness    0
# liveness            0
# tempo               0
# loudness_db         0
# duration_sec        0
# popularity          0
# previous_skips      0
# repeat_count        0
# skip                0
# dtype: int64
